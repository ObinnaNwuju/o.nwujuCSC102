# %%
# Compound Interest Calculation

# Loop for Principal (P)
while True:
    P = input("Enter the Principal amount (P): ")
    try:
        P = float(P)  # convert to float
        break
    except ValueError:
        print("Invalid input. Please enter a numerical value.")

# Loop for Rate (R)
while True:
    R = input("Enter the Rate of interest (R) in percentage: ")
    try:
        R = float(R)
        break
    except ValueError:
        print("Invalid input. Please enter a numerical value.")

# Loop for Time (T)
while True:
    T = input("Enter the Time period in years (T): ")
    try:
        T = float(T)
        break
    except ValueError:
        print("Invalid input. Please enter a numerical value.")

# Loop for Compounding Frequency (n)
while True:
    n = input("Enter the number of times interest is compounded per year (n): ")
    try:
        n = int(n)
        if n <= 0:
            print("Please enter a positive whole number.")
            continue
        break
    except ValueError:
        print("Invalid input. Please enter a whole number.")

# Calculate Compound Interest
A = P * (1 + (R / (100 * n))) ** (n * T)
print("Final Amount with Compound Interest is:", A)
# Out:
# Enter the Principal amount (P):  56
# Enter the Rate of interest (R) in percentage:  678
# Enter the Time period in years (T):  35
# Enter the number of times interest is compounded per year (n):  4
# Final Amount with Compound Interest is: 1.0627124296693673e+62

# %% [markdown]
# ![diagram-export-3-7-2026-11_50_18-PM.png](attachment:716fdb1b-4884-47c7-8b1b-566aee7ed3db.png)
